# %%
#import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import csv
import seaborn as sns
import math
from PIL import Image

# %%
def dead_tube_check(input_file):
    df = pd.read_csv(input_file, delimiter=",")

    if len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)]) > 0:
        number=len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
        print(str(number) + " dead tubes are suppressed.")
        display(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
    else:
        display("There are no dead tubes.")

# %%
def summary_hist(input_file, save_folder):
    df = pd.read_csv(input_file, delimiter=",")
    df=df.loc[df['Resolution[um]']>0]
    df.hist(column=['T0[ns]', 'TMax[ns]',
        'ADC_peak[ns]', 'ADC_width[ns]', 'Resolution[um]', 'Efficiency'], bins=30, layout =(2,3), figsize= (15,5), color='skyblue', edgecolor='black', grid=False)
    plt.suptitle(input_file)
    #plt.show()
    plt.savefig(save_folder+"\\"+"hist.png", bbox_inches="tight")
    plt.close()

# %%
def heatmaps(input_file, save_path):

    heatmap_files=[]
    df = pd.read_csv(input_file, delimiter=",")
    df=df.loc[df['Resolution[um]']>0]
    df_rename=df.rename(columns={"Column": "Tube Number"}, inplace=False)
    for col in ['T0[ns]', 'TMax[ns]',
        'ADC_peak[ns]', 'ADC_width[ns]', 'Resolution[um]', 'Efficiency']:

        #Create heatmap
        heatmap_data=df_rename.pivot_table(index=df_rename["Layer"], columns=df_rename["Tube Number"], values=col)
        dcol=5
        min=0
        max=df_rename["Tube Number"].max()
        nsteps=int(max/dcol)+1
        arr=np.linspace(min,max,nsteps, dtype=int)
        heatmap_sorted=heatmap_data.sort_values(by='Layer', ascending=False)
        plt.figure(figsize=(5,3))
        ax=plt.axes()
        plotting=sns.heatmap(heatmap_sorted, annot=False, cmap='viridis', ax=ax, )
        plotting.set_xticks(arr)
        plotting.set_xticklabels(list(map(str,arr)))
        title, throwaway=input_file.split(".txt")
        plotting.set_title(col + " " + title)
        #plt.show()
        plt.savefig(save_path+"\\"+col+".png", bbox_inches="tight")
        plt.close()

        heatmap_files.append(col+".png")
    
    return heatmap_files

# %%
# function to create folder

def create_folder(file, desired_location):
    keep, throwaway=file.split(".txt")
    keep=keep+"_plots"
    new_folder_path=desired_location+r"\\"+keep
    
    if os.path.isdir(new_folder_path):
        print(f"The folder '{new_folder_path}' exists.")
    else:
        os.mkdir(new_folder_path)
    return new_folder_path

# %%
def concat_imgs(list_of_files, folder_path, columns, new_file_name):
    widths=[]
    heights=[]
    images=[]
    for i in list_of_files:
        img=Image.open(folder_path+"\\"+i)
        images.append(img)
        w,h=img.size
        widths.append(w)
        heights.append(h)
    #print(widths)
    indiv_w=np.max(widths)
    indiv_h=np.max(heights)

    rows=rows=math.ceil(len(list_of_files)/columns)
    
    new_image=Image.new('RGB',(int(indiv_w*columns),int(indiv_h*rows)), (255,255,255))
    

    # put plots on new image
    for i in range(0,len(images)):
        #find row to populate
        new_row=math.floor(i/columns)

        #find col to populate
        new_col=math.ceil(i % columns)

        new_image.paste(images[i], ((new_col*indiv_w), (new_row*indiv_h)))

    # save
    new_image.save(folder_path+"\\"+new_file_name+".png")

# %%
def filter_func(input_file, parameter, spec, greater_less):
    df = pd.read_csv(input_file, delimiter=",")

    #Make cuts to identify outlier tubes
    if parameter=="to":
        sorted_df = df.sort_values(by="T0[ns]")
        if greater_less=="G":
            filtered_df=sorted_df[(sorted_df["T0[ns]"]>spec)].iloc[:,:]
            display(filtered_df)
        elif greater_less=="L":
            filtered_df=sorted_df[(sorted_df["T0[ns]"]<spec)].iloc[:,:]
            display(filtered_df)
        else:
            print("No filtering specified")
    if parameter=="tmax":
        sorted_df = df.sort_values(by="TMax[ns]")
        if greater_less=="G":
            filtered_df=sorted_df[(sorted_df["TMax[ns]"]>spec)].iloc[:,:]
            display(filtered_df)
        elif greater_less=="L":
            filtered_df=sorted_df[(sorted_df["TMax[ns]"]<spec)].iloc[:,:]
            display(filtered_df)
        else:
            print("No filtering specified")
    if parameter=="adcp":
        sorted_df = df.sort_values(by="ADC_peak[ns]")
        if greater_less=="G":
            filtered_df=sorted_df[(sorted_df["ADC_peak[ns]"]>spec)].iloc[:,:]
            display(filtered_df)
        elif greater_less=="L":
            filtered_df=sorted_df[(sorted_df["ADC_peak[ns]"]<spec)].iloc[:,:]
            display(filtered_df)
        else:
            print("No filtering specified")
    if parameter=="adcw":
        sorted_df = df.sort_values(by="ADC_width[ns]")
        if greater_less=="G":
            filtered_df=sorted_df[(sorted_df["ADC_width[ns]"]>spec)].iloc[:,:]
            display(filtered_df)
        elif greater_less=="L":
            filtered_df=sorted_df[(sorted_df["ADC_width[ns]"]<spec)].iloc[:,:]
            display(filtered_df)
        else:
            print("No filtering specified")
    if parameter=="res":
        sorted_df = df.sort_values(by="Resolution[um]")
        if greater_less=="G":
            filtered_df=sorted_df[(sorted_df["Resolution[um]"]>spec)].iloc[:,:]
            display(filtered_df)
        elif greater_less=="L":
            filtered_df=sorted_df[(sorted_df["Resolution[um]"]<spec)].iloc[:,:]
            display(filtered_df)
        else:
            print("No filtering specified")
    if parameter=="eff":
        sorted_df = df.sort_values(by="Efficiency")
        if greater_less=="G":
            filtered_df=sorted_df[(sorted_df["Efficiency"]>spec)].iloc[:,:]
            display(filtered_df)
        elif greater_less=="L":
            filtered_df=sorted_df[(sorted_df["Efficiency"]<spec)].iloc[:,:]
            display(filtered_df)
        else:
            print("No filtering specified")
    return filtered_df

# %%
def grab(filtered_dataframe, spectra_folder):
    
    wanted_adc_files=[]
    wanted_tdc_files=[]
    adc_titles=[]
    tdc_titles=[]

    for i in range(0,len(filtered_dataframe["Column"])):
        # Construct ADC filenames:
        col=filtered_dataframe.iloc[i,0]
        layer=filtered_dataframe.iloc[i,1]
        tdc_id=filtered_dataframe.iloc[i,2]
        tdc_ch_id=filtered_dataframe.iloc[i,3]

        ADC_file="TestData_tdc_"+str(tdc_id)+"_channel_"+str(tdc_ch_id)+"_adc_time_spectrum.png"
        
        ADC_title=f"ADC: Layer {layer} Tube {col} TDC_ID {tdc_id} TDC_Ch_ID {tdc_ch_id}" 

        # Construct TDC filenames:
        TDC_file="TestData_tdc_"+str(tdc_id)+"_channel_"+str(tdc_ch_id)+"_tdc_time_spectrum_corrected.png"

        TDC_title=f"TDC: Layer {layer} Tube {col} TDC_ID {tdc_id} TDC_Ch_ID {tdc_ch_id}" 

        wanted_adc_files.append(ADC_file)
        wanted_tdc_files.append(TDC_file)
        adc_titles.append(ADC_title)
        tdc_titles.append(TDC_title)
    return wanted_adc_files, wanted_tdc_files, adc_titles, tdc_titles

# %%
def new_title(adc_list, tdc_list, folder_with_pngs, adc_titles, tdc_titles):
    
    imgs_with_title=[]

    for i in range(0,len(adc_list)):
        old_img_path=folder_with_pngs+"\\"+adc_list[i]
        if os.path.exists(old_img_path):
            old_img=Image.open(old_img_path)
            fig,ax=plt.subplots()
            ax.imshow(old_img)
            ax.set_axis_off()
            ax.set_title(adc_titles[i])
            new_img_path=folder_with_pngs+"\\"+"filtered"+"\\"+adc_list[i]
            plt.savefig(new_img_path, bbox_inches="tight")
            plt.close()
            new_img=Image.open(new_img_path)
            imgs_with_title.append(new_img)
        else:
            print("No spectra available. Check if tube is dead.")
    for i in range(0,len(adc_list)):
        old_img_path=folder_with_pngs+"\\"+tdc_list[i]
        if os.path.exists(old_img_path):
            old_img=Image.open(old_img_path)
            fig,ax=plt.subplots()
            ax.imshow(old_img)
            ax.set_axis_off()
            ax.set_title(tdc_titles[i])
            new_img_path=folder_with_pngs+"\\"+"filtered"+"\\"+tdc_list[i]
            plt.savefig(new_img_path, bbox_inches="tight")
            plt.close()
            new_img=Image.open(new_img_path)
            imgs_with_title.append(new_img)
        else:
            print("No spectra available. Check if tube is dead.")

# %%
def calc_stats(run):
    df = pd.read_csv(run, delimiter=",") #import txt file
    df=df.loc[df['Resolution[um]']>0] #select alive tubes
    mins=df.min().to_frame()
    mins.columns=["Min"]
    maxes=df.max().to_frame()
    maxes.columns=["Max"]
    means=df.mean().to_frame()
    means.columns=["Mean"]
    summary=pd.concat([mins,maxes["Max"],means["Mean"]],axis=1)
    summary=summary.drop(labels=["Column", "Layer", "TDC_id", "TDC_Ch_id"], axis=0, inplace=False)
    return summary

# %%
#Choose run of interest
# run="Mod1_BIS1C02_CosmicRay_Thr114.txt"
# location=r"C:\Users\svene\OneDrive\Documents\Tufts\Research\qual\working_files"

# #Create folder for plots
# path=create_folder(run, location)

# #Write path for downloaded spectra
# keep,throwaway=path.split("_plots")
# spectra_path=keep+"_spectra"+"\\"+"T0Fits"

# #Generate summary plots
# dead_tube_check(run)
# summary_hist(run,path)
# file_list=heatmaps(run, path)
# concat_imgs(file_list,path,3,"heatmaps")

# %%
# filtering

# apply filters
# print("t0 filter")
# #t0_filter=filter_func(run, "to",277.5, "L")

# print("tmax filter")
# tmax_filter1=filter_func(run, "tmax",188.5, "L")
# tmax_filter2=filter_func(run, "tmax",196, "G")

# print("adcp filter")
# adcp_filter=filter_func(run, "adcp",215, "G")

# print("adcw filter")
# # adcw_filter=filter_func(run, "adcw",120, "L")

# print("res filter")
# res_filter=filter_func(run, "res",115, "G")

# print("eff filter")
# # eff_filter=filter_func(run, "eff",.995, "G")

# filters_concat=pd.concat([tmax_filter1, tmax_filter2, adcp_filter, res_filter])
# f_concat_nodupe=filters_concat.drop_duplicates()

# display(f_concat_nodupe.sort_values(by=["TDC_id", "TDC_Ch_id"]))

# %%
# re-title plots and save in filtered folder

wanted_adcs, wanted_tdcs, a_titles, t_titles=grab(f_concat_nodupe,spectra_path)
new_title(wanted_adcs,wanted_tdcs, spectra_path,a_titles, t_titles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 # re-title plots and save in filtered folder
# ----> 3 wanted_adcs, wanted_tdcs, a_titles, t_titles=grab(f_concat_nodupe,spectra_path)
#       4 new_title(wanted_adcs,wanted_tdcs, spectra_path,a_titles, t_titles)
#
# NameError: name 'f_concat_nodupe' is not defined

# %%
# Get list of actual spectra in filtered folder
filtered_folder=spectra_path+"\\"+"filtered"
all_files=os.listdir(filtered_folder)
filtered_files=[]
for i in all_files:
    if "TestData" in i:
        filtered_files.append(i)

# %%
# Create summary image with all spectra of interest
concat_imgs(filtered_files, filtered_folder, 4, "Selected Images")

# %%
# print max, min, avg info

stats=calc_stats(run)
display(stats)
# Out:
#                        Min         Max        Mean
# T0[ns]          298.232416  317.022025  305.944168
# TMax[ns]        187.873341  196.230461  191.303900
# ADC_peak[ns]    118.775709  218.437963  160.128684
# ADC_width[ns]    20.636033   34.029857   26.911597
# Resolution[um]   84.582900  124.268147   95.831909
# Efficiency        0.976088    0.997660    0.990649

# %%
# Get list of all spectra
all_folder=spectra_path+"\\"
all_files=os.listdir(all_folder)
# print(all_folder)
# print(all_files)

pngs=[]
for i in all_files:
    print(i)
    if "TestData" in i:
        pngs.append(i)
print(pngs)
        
# Create summary image with every spectra generated
concat_imgs(pngs, all_folder, 4, "All Images")
# Out:
# adchist.png
# All Images.png
# filtered
# re_title
# TestData_tdc_0_adc_time_spectrum.png
# TestData_tdc_0_channel_0_adc_time_spectrum.png
# TestData_tdc_0_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_10_adc_time_spectrum.png
# TestData_tdc_0_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_11_adc_time_spectrum.png
# TestData_tdc_0_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_12_adc_time_spectrum.png
# TestData_tdc_0_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_13_adc_time_spectrum.png
# TestData_tdc_0_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_14_adc_time_spectrum.png
# TestData_tdc_0_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_15_adc_time_spectrum.png
# TestData_tdc_0_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_16_adc_time_spectrum.png
# TestData_tdc_0_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_17_adc_time_spectrum.png
# TestData_tdc_0_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_18_adc_time_spectrum.png
# TestData_tdc_0_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_19_adc_time_spectrum.png
# TestData_tdc_0_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_1_adc_time_spectrum.png
# TestData_tdc_0_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_2_adc_time_spectrum.png
# TestData_tdc_0_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_3_adc_time_spectrum.png
# TestData_tdc_0_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_4_adc_time_spectrum.png
# TestData_tdc_0_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_5_adc_time_spectrum.png
# TestData_tdc_0_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_6_adc_time_spectrum.png
# TestData_tdc_0_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_7_adc_time_spectrum.png
# TestData_tdc_0_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_8_adc_time_spectrum.png
# TestData_tdc_0_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_0_channel_9_adc_time_spectrum.png
# TestData_tdc_0_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_0_tdc_time_spectrum_corrected.png
# TestData_tdc_10_adc_time_spectrum.png
# TestData_tdc_10_channel_0_adc_time_spectrum.png
# TestData_tdc_10_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_10_adc_time_spectrum.png
# TestData_tdc_10_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_11_adc_time_spectrum.png
# TestData_tdc_10_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_12_adc_time_spectrum.png
# TestData_tdc_10_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_13_adc_time_spectrum.png
# TestData_tdc_10_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_14_adc_time_spectrum.png
# TestData_tdc_10_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_15_adc_time_spectrum.png
# TestData_tdc_10_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_16_adc_time_spectrum.png
# TestData_tdc_10_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_17_adc_time_spectrum.png
# TestData_tdc_10_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_18_adc_time_spectrum.png
# TestData_tdc_10_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_19_adc_time_spectrum.png
# TestData_tdc_10_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_1_adc_time_spectrum.png
# TestData_tdc_10_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_20_adc_time_spectrum.png
# TestData_tdc_10_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_21_adc_time_spectrum.png
# TestData_tdc_10_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_22_adc_time_spectrum.png
# TestData_tdc_10_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_23_adc_time_spectrum.png
# TestData_tdc_10_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_2_adc_time_spectrum.png
# TestData_tdc_10_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_3_adc_time_spectrum.png
# TestData_tdc_10_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_4_adc_time_spectrum.png
# TestData_tdc_10_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_5_adc_time_spectrum.png
# TestData_tdc_10_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_6_adc_time_spectrum.png
# TestData_tdc_10_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_7_adc_time_spectrum.png
# TestData_tdc_10_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_8_adc_time_spectrum.png
# TestData_tdc_10_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_10_channel_9_adc_time_spectrum.png
# TestData_tdc_10_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_10_tdc_time_spectrum_corrected.png
# TestData_tdc_11_adc_time_spectrum.png
# TestData_tdc_11_channel_0_adc_time_spectrum.png
# TestData_tdc_11_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_10_adc_time_spectrum.png
# TestData_tdc_11_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_11_adc_time_spectrum.png
# TestData_tdc_11_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_12_adc_time_spectrum.png
# TestData_tdc_11_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_13_adc_time_spectrum.png
# TestData_tdc_11_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_14_adc_time_spectrum.png
# TestData_tdc_11_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_15_adc_time_spectrum.png
# TestData_tdc_11_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_16_adc_time_spectrum.png
# TestData_tdc_11_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_17_adc_time_spectrum.png
# TestData_tdc_11_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_18_adc_time_spectrum.png
# TestData_tdc_11_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_19_adc_time_spectrum.png
# TestData_tdc_11_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_1_adc_time_spectrum.png
# TestData_tdc_11_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_20_adc_time_spectrum.png
# TestData_tdc_11_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_21_adc_time_spectrum.png
# TestData_tdc_11_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_22_adc_time_spectrum.png
# TestData_tdc_11_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_23_adc_time_spectrum.png
# TestData_tdc_11_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_2_adc_time_spectrum.png
# TestData_tdc_11_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_3_adc_time_spectrum.png
# TestData_tdc_11_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_4_adc_time_spectrum.png
# TestData_tdc_11_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_5_adc_time_spectrum.png
# TestData_tdc_11_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_6_adc_time_spectrum.png
# TestData_tdc_11_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_7_adc_time_spectrum.png
# TestData_tdc_11_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_8_adc_time_spectrum.png
# TestData_tdc_11_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_11_channel_9_adc_time_spectrum.png
# TestData_tdc_11_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_11_tdc_time_spectrum_corrected.png
# TestData_tdc_1_adc_time_spectrum.png
# TestData_tdc_1_channel_0_adc_time_spectrum.png
# TestData_tdc_1_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_1_channel_11_adc_time_spectrum.png
# TestData_tdc_1_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_1_channel_12_adc_time_spectrum.png
# TestData_tdc_1_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_1_channel
channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_27_channel_8_adc_time_spectrum.png
# TestData_tdc_27_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_27_channel_9_adc_time_spectrum.png
# TestData_tdc_27_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_27_tdc_time_spectrum_corrected.png
# TestData_tdc_28_adc_time_spectrum.png
# TestData_tdc_28_channel_0_adc_time_spectrum.png
# TestData_tdc_28_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_10_adc_time_spectrum.png
# TestData_tdc_28_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_11_adc_time_spectrum.png
# TestData_tdc_28_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_12_adc_time_spectrum.png
# TestData_tdc_28_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_13_adc_time_spectrum.png
# TestData_tdc_28_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_14_adc_time_spectrum.png
# TestData_tdc_28_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_15_adc_time_spectrum.png
# TestData_tdc_28_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_16_adc_time_spectrum.png
# TestData_tdc_28_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_17_adc_time_spectrum.png
# TestData_tdc_28_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_18_adc_time_spectrum.png
# TestData_tdc_28_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_19_adc_time_spectrum.png
# TestData_tdc_28_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_1_adc_time_spectrum.png
# TestData_tdc_28_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_20_adc_time_spectrum.png
# TestData_tdc_28_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_21_adc_time_spectrum.png
# TestData_tdc_28_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_22_adc_time_spectrum.png
# TestData_tdc_28_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_23_adc_time_spectrum.png
# TestData_tdc_28_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_2_adc_time_spectrum.png
# TestData_tdc_28_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_3_adc_time_spectrum.png
# TestData_tdc_28_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_4_adc_time_spectrum.png
# TestData_tdc_28_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_5_adc_time_spectrum.png
# TestData_tdc_28_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_6_adc_time_spectrum.png
# TestData_tdc_28_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_7_adc_time_spectrum.png
# TestData_tdc_28_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_8_adc_time_spectrum.png
# TestData_tdc_28_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_28_channel_9_adc_time_spectrum.png
# TestData_tdc_28_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_28_tdc_time_spectrum_corrected.png
# TestData_tdc_29_adc_time_spectrum.png
# TestData_tdc_29_channel_0_adc_time_spectrum.png
# TestData_tdc_29_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_10_adc_time_spectrum.png
# TestData_tdc_29_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_11_adc_time_spectrum.png
# TestData_tdc_29_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_12_adc_time_spectrum.png
# TestData_tdc_29_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_13_adc_time_spectrum.png
# TestData_tdc_29_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_14_adc_time_spectrum.png
# TestData_tdc_29_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_15_adc_time_spectrum.png
# TestData_tdc_29_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_16_adc_time_spectrum.png
# TestData_tdc_29_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_17_adc_time_spectrum.png
# TestData_tdc_29_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_18_adc_time_spectrum.png
# TestData_tdc_29_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_19_adc_time_spectrum.png
# TestData_tdc_29_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_1_adc_time_spectrum.png
# TestData_tdc_29_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_20_adc_time_spectrum.png
# TestData_tdc_29_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_21_adc_time_spectrum.png
# TestData_tdc_29_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_22_adc_time_spectrum.png
# TestData_tdc_29_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_23_adc_time_spectrum.png
# TestData_tdc_29_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_2_adc_time_spectrum.png
# TestData_tdc_29_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_3_adc_time_spectrum.png
# TestData_tdc_29_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_4_adc_time_spectrum.png
# TestData_tdc_29_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_5_adc_time_spectrum.png
# TestData_tdc_29_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_6_adc_time_spectrum.png
# TestData_tdc_29_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_7_adc_time_spectrum.png
# TestData_tdc_29_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_8_adc_time_spectrum.png
# TestData_tdc_29_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_29_channel_9_adc_time_spectrum.png
# TestData_tdc_29_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_29_tdc_time_spectrum_corrected.png
# TestData_tdc_2_adc_time_spectrum.png
# TestData_tdc_2_channel_0_adc_time_spectrum.png
# TestData_tdc_2_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_10_adc_time_spectrum.png
# TestData_tdc_2_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_11_adc_time_spectrum.png
# TestData_tdc_2_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_12_adc_time_spectrum.png
# TestData_tdc_2_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_13_adc_time_spectrum.png
# TestData_tdc_2_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_14_adc_time_spectrum.png
# TestData_tdc_2_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_15_adc_time_spectrum.png
# TestData_tdc_2_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_16_adc_time_spectrum.png
# TestData_tdc_2_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_17_adc_time_spectrum.png
# TestData_tdc_2_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_18_adc_time_spectrum.png
# TestData_tdc_2_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_19_adc_time_spectrum.png
# TestData_tdc_2_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_1_adc_time_spectrum.png
# TestData_tdc_2_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_20_adc_time_spectrum.png
# TestData_tdc_2_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_21_adc_time_spectrum.png
# TestData_tdc_2_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_22_adc_time_spectrum.png
# TestData_tdc_2_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_23_adc_time_spectrum.png
# TestData_tdc_2_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_2_adc_time_spectrum.png
# TestData_tdc_2_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_3_adc_time_spectrum.png
# TestData_tdc_2_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_4_adc_time_spectrum.png
# TestData_tdc_2_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_5_adc_time_spectrum.png
# TestData_tdc_2_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_6_adc_time_spectrum.png
# TestData_tdc_2_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_7_adc_time_spectrum.png
# TestData_tdc_2_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_8_adc_time_spectrum.png
# TestData_tdc_2_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_2_channel_9_adc_time_spectrum.png
# TestData_tdc_2_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_2_tdc_time_spectrum_corrected.png
# TestData_tdc_30_adc_time_spectrum.png
# TestData_tdc_30_channel_0_adc_time_spectrum.png
# TestData_tdc_30_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_10_adc_time_spectrum.png
# TestData_tdc_30_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_11_adc_time_spectrum.png
# TestData_tdc_30_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_12_adc_time_spectrum.png
# TestData_tdc_30_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_13_adc_time_spectrum.png
# TestData_tdc_30_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_14_adc_time_spectrum.png
# TestData_tdc_30_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_15_adc_time_spectrum.png
# TestData_tdc_30_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_16_adc_time_spectrum.png
# TestData_tdc_30_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_17_adc_time_spectrum.png
# TestData_tdc_30_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_18_adc_time_spectrum.png
# TestData_tdc_30_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_19_adc_time_spectrum.png
# TestData_tdc_30_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_1_adc_time_spectrum.png
# TestData_tdc_30_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_2_adc_time_spectrum.png
# TestData_tdc_30_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_3_adc_time_spectrum.png
# TestData_tdc_30_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_4_adc_time_spectrum.png
# TestData_tdc_30_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_5_adc_time_spectrum.png
# TestData_tdc_30_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_6_adc_time_spectrum.png
# TestData_tdc_30_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_7_adc_time_spectrum.png
# TestData_tdc_30_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_8_adc_time_spectrum.png
# TestData_tdc_30_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_30_channel_9_adc_time_spectrum.png
# TestData_tdc_30_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_30_tdc_time_spectrum_corrected.png
# TestData_tdc_31_adc_time_spectrum.png
# TestData_tdc_31_channel_0_adc_time_spectrum.png
# TestData_tdc_31_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_10_adc_time_spectrum.png
# TestData_tdc_31_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_11_adc_time_spectrum.png
# TestData_tdc_31_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_12_adc_time_spectrum.png
# TestData_tdc_31_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_13_adc_time_spectrum.png
# TestData_tdc_31_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_14_adc_time_spectrum.png
# TestData_tdc_31_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_15_adc_time_spectrum.png
# TestData_tdc_31_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_16_adc_time_spectrum.png
# TestData_tdc_31_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_17_adc_time_spectrum.png
# TestData_tdc_31_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_18_adc_time_spectrum.png
# TestData_tdc_31_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_19_adc_time_spectrum.png
# TestData_tdc_31_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_1_adc_time_spectrum.png
# TestData_tdc_31_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_2_adc_time_spectrum.png
# TestData_tdc_31_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_3_adc_time_spectrum.png
# TestData_tdc_31_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_4_adc_time_spectrum.png
# TestData_tdc_31_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_5_adc_time_spectrum.png
# TestData_tdc_31_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_6_adc_time_spectrum.png
# TestData_tdc_31_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_7_adc_time_spectrum.png
# TestData_tdc_31_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_8_adc_time_spectrum.png
# TestData_tdc_31_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_31_channel_9_adc_time_spectrum.png
# TestData_tdc_31_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_31_tdc_time_spectrum_corrected.png
# TestData_tdc_3_adc_time_spectrum.png
# TestData_tdc_3_channel_0_adc_time_spectrum.png
# TestData_tdc_3_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_10_adc_time_spectrum.png
# TestData_tdc_3_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_11_adc_time_spectrum.png
# TestData_tdc_3_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_12_adc_time_spectrum.png
# TestData_tdc_3_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_13_adc_time_spectrum.png
# TestData_tdc_3_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_14_adc_time_spectrum.png
# TestData_tdc_3_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_15_adc_time_spectrum.png
# TestData_tdc_3_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_16_adc_time_spectrum.png
# TestData_tdc_3_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_17_adc_time_spectrum.png
# TestData_tdc_3_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_18_adc_time_spectrum.png
# TestData_tdc_3_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_19_adc_time_spectrum.png
# TestData_tdc_3_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_1_adc_time_spectrum.png
# TestData_tdc_3_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_20_adc_time_spectrum.png
# TestData_tdc_3_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_21_adc_time_spectrum.png
# TestData_tdc_3_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_22_adc_time_spectrum.png
# TestData_tdc_3_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_23_adc_time_spectrum.png
# TestData_tdc_3_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_3_adc_time_spectrum.png
# TestData_tdc_3_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_4_adc_time_spectrum.png
# TestData_tdc_3_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_5_adc_time_spectrum.png
# TestData_tdc_3_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_6_adc_time_spectrum.png
# TestData_tdc_3_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_7_adc_time_spectrum.png
# TestData_tdc_3_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_8_adc_time_spectrum.png
# TestData_tdc_3_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_3_channel_9_adc_time_spectrum.png
# TestData_tdc_3_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_3_tdc_time_spectrum_corrected.png
# TestData_tdc_4_adc_time_spectrum.png
# TestData_tdc_4_channel_0_adc_time_spectrum.png
# TestData_tdc_4_channel_0_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_10_adc_time_spectrum.png
# TestData_tdc_4_channel_10_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_11_adc_time_spectrum.png
# TestData_tdc_4_channel_11_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_12_adc_time_spectrum.png
# TestData_tdc_4_channel_12_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_13_adc_time_spectrum.png
# TestData_tdc_4_channel_13_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_14_adc_time_spectrum.png
# TestData_tdc_4_channel_14_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_15_adc_time_spectrum.png
# TestData_tdc_4_channel_15_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_16_adc_time_spectrum.png
# TestData_tdc_4_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_17_adc_time_spectrum.png
# TestData_tdc_4_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_18_adc_time_spectrum.png
# TestData_tdc_4_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_19_adc_time_spectrum.png
# TestData_tdc_4_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_1_adc_time_spectrum.png
# TestData_tdc_4_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_20_adc_time_spectrum.png
# TestData_tdc_4_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel_21_adc_time_spectrum.png
# TestData_tdc_4_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_4_channel
tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_16_adc_time_spectrum.png
# TestData_tdc_9_channel_16_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_17_adc_time_spectrum.png
# TestData_tdc_9_channel_17_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_18_adc_time_spectrum.png
# TestData_tdc_9_channel_18_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_19_adc_time_spectrum.png
# TestData_tdc_9_channel_19_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_1_adc_time_spectrum.png
# TestData_tdc_9_channel_1_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_20_adc_time_spectrum.png
# TestData_tdc_9_channel_20_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_21_adc_time_spectrum.png
# TestData_tdc_9_channel_21_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_22_adc_time_spectrum.png
# TestData_tdc_9_channel_22_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_23_adc_time_spectrum.png
# TestData_tdc_9_channel_23_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_2_adc_time_spectrum.png
# TestData_tdc_9_channel_2_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_3_adc_time_spectrum.png
# TestData_tdc_9_channel_3_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_4_adc_time_spectrum.png
# TestData_tdc_9_channel_4_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_5_adc_time_spectrum.png
# TestData_tdc_9_channel_5_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_6_adc_time_spectrum.png
# TestData_tdc_9_channel_6_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_7_adc_time_spectrum.png
# TestData_tdc_9_channel_7_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_8_adc_time_spectrum.png
# TestData_tdc_9_channel_8_tdc_time_spectrum_corrected.png
# TestData_tdc_9_channel_9_adc_time_spectrum.png
# TestData_tdc_9_channel_9_tdc_time_spectrum_corrected.png
# TestData_tdc_9_tdc_time_spectrum_corrected.png
# ['TestData_tdc_0_adc_time_spectrum.png', 'TestData_tdc_0_channel_0_adc_time_spectrum.png', 'TestData_tdc_0_channel_0_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_10_adc_time_spectrum.png', 'TestData_tdc_0_channel_10_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_11_adc_time_spectrum.png', 'TestData_tdc_0_channel_11_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_12_adc_time_spectrum.png', 'TestData_tdc_0_channel_12_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_13_adc_time_spectrum.png', 'TestData_tdc_0_channel_13_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_14_adc_time_spectrum.png', 'TestData_tdc_0_channel_14_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_15_adc_time_spectrum.png', 'TestData_tdc_0_channel_15_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_16_adc_time_spectrum.png', 'TestData_tdc_0_channel_16_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_17_adc_time_spectrum.png', 'TestData_tdc_0_channel_17_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_18_adc_time_spectrum.png', 'TestData_tdc_0_channel_18_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_19_adc_time_spectrum.png', 'TestData_tdc_0_channel_19_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_1_adc_time_spectrum.png', 'TestData_tdc_0_channel_1_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_2_adc_time_spectrum.png', 'TestData_tdc_0_channel_2_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_3_adc_time_spectrum.png', 'TestData_tdc_0_channel_3_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_4_adc_time_spectrum.png', 'TestData_tdc_0_channel_4_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_5_adc_time_spectrum.png', 'TestData_tdc_0_channel_5_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_6_adc_time_spectrum.png', 'TestData_tdc_0_channel_6_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_7_adc_time_spectrum.png', 'TestData_tdc_0_channel_7_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_8_adc_time_spectrum.png', 'TestData_tdc_0_channel_8_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_channel_9_adc_time_spectrum.png', 'TestData_tdc_0_channel_9_tdc_time_spectrum_corrected.png', 'TestData_tdc_0_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_adc_time_spectrum.png', 'TestData_tdc_10_channel_0_adc_time_spectrum.png', 'TestData_tdc_10_channel_0_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_10_adc_time_spectrum.png', 'TestData_tdc_10_channel_10_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_11_adc_time_spectrum.png', 'TestData_tdc_10_channel_11_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_12_adc_time_spectrum.png', 'TestData_tdc_10_channel_12_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_13_adc_time_spectrum.png', 'TestData_tdc_10_channel_13_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_14_adc_time_spectrum.png', 'TestData_tdc_10_channel_14_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_15_adc_time_spectrum.png', 'TestData_tdc_10_channel_15_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_16_adc_time_spectrum.png', 'TestData_tdc_10_channel_16_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_17_adc_time_spectrum.png', 'TestData_tdc_10_channel_17_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_18_adc_time_spectrum.png', 'TestData_tdc_10_channel_18_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_19_adc_time_spectrum.png', 'TestData_tdc_10_channel_19_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_1_adc_time_spectrum.png', 'TestData_tdc_10_channel_1_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_20_adc_time_spectrum.png', 'TestData_tdc_10_channel_20_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_21_adc_time_spectrum.png', 'TestData_tdc_10_channel_21_tdc_time_spectrum_corrected.png', 'TestData_tdc_10_channel_22_adc_time_spectrum.png', 'Tes ...

# %%
def new_title_edit(adc_list, tdc_list, folder_with_pngs, adc_titles, tdc_titles):
    
    imgs_with_title=[]

    for i in range(0,len(adc_list)):
        old_img_path=folder_with_pngs+"\\"+adc_list[i]
        if os.path.exists(old_img_path):
            old_img=Image.open(old_img_path)
            fig,ax=plt.subplots()
            ax.imshow(old_img)
            ax.set_axis_off()
            ax.set_title(adc_titles[i])
            new_img_path=folder_with_pngs+"\\"+"re_title"+"\\"+adc_list[i]
            plt.savefig(new_img_path, bbox_inches="tight")
            plt.close()
            new_img=Image.open(new_img_path)
            imgs_with_title.append(new_img)
        else:
            print("No spectra available. Check if tube is dead.")
    for i in range(0,len(adc_list)):
        old_img_path=folder_with_pngs+"\\"+tdc_list[i]
        if os.path.exists(old_img_path):
            old_img=Image.open(old_img_path)
            fig,ax=plt.subplots()
            ax.imshow(old_img)
            ax.set_axis_off()
            ax.set_title(tdc_titles[i])
            new_img_path=folder_with_pngs+"\\"+"re_title"+"\\"+tdc_list[i]
            plt.savefig(new_img_path, bbox_inches="tight")
            plt.close()
            new_img=Image.open(new_img_path)
            imgs_with_title.append(new_img)
        else:
            print("No spectra available. Check if tube is dead.")

# %%
# re-title plots and save in filtered folder

df = pd.read_csv(run, delimiter=",")

if len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)]) > 0:
    number=len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
    print(str(number) + " dead tubes are suppressed.")
    display(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
    new_df=df.loc[(df['Resolution[um]']!=0) & (df['Efficiency']!=0)]
else:
    display("There are no dead tubes.")
display(new_df)
print(len(df))
print(len(new_df))

wanted_adcs, wanted_tdcs, a_titles, t_titles=grab(new_df,spectra_path)

new_title_edit(wanted_adcs,wanted_tdcs, spectra_path,a_titles, t_titles)
# Out:
# 3 dead tubes are suppressed.
#      Column  Layer  TDC_id  TDC_Ch_id  T0[ns]  TMax[ns]  ADC_peak[ns]  \
# 20        3      5       1         10     0.0       0.0           0.0
# 44        6      5       3          2     0.0       0.0           0.0
# 100      13      5       5          6     0.0       0.0           0.0
#
#      ADC_width[ns]  Resolution[um]  Efficiency
# 20             0.0             0.0         0.0
# 44             0.0             0.0         0.0
# 100            0.0             0.0         0.0
#      Column  Layer  TDC_id  TDC_Ch_id      T0[ns]    TMax[ns]  ADC_peak[ns]  \
# 0         1      1       0          2  311.656338  194.537904    153.631875
# 1         1      2       0          3  307.849775  193.743684    125.690062
# 2         1      3       0          0  313.880833  192.809537    197.681690
# 3         1      4       0          1  313.909434  194.701392    198.361197
# 4         1      5       1          2  303.065128  196.230461    158.084328
# ..      ...    ...     ...        ...         ...         ...           ...
# 555      70      4      30         17  305.868329  191.853092    160.573535
# 556      70      5      31         18  302.928492  192.221292    144.646666
# 557      70      6      31         19  304.574110  190.728151    160.835571
# 558      70      7      31         16  302.005443  190.767748    140.788477
# 559      70      8      31         17  302.993910  191.062955    145.447405
#
#      ADC_width[ns]  Resolution[um]  Efficiency
# 0        25.852421      104.888102    0.976088
# 1        21.734910       96.422896    0.987845
# 2        32.969465       99.027017    0.990591
# 3        32.807924       95.678462    0.994735
# 4        28.195737       91.095016    0.997251
# ..             ...             ...         ...
# 555      27.295963       91.209327    0.991514
# 556      25.638446       90.464816    0.997660
# 557      28.645116       90.614853    0.996604
# 558      23.766992       96.575606    0.995259
# 559      24.528338       96.830983    0.983681
#
# [557 rows x 10 columns]
# 560
# 557
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 18
#      14 print(len(new_df))
#      16 wanted_adcs, wanted_tdcs, a_titles, t_titles=grab(new_df,spectra_path)
# ---> 18 new_title_edit(wanted_adcs,wanted_tdcs, spectra_path,a_titles, t_titles)
#
# Cell In[19], line 29, in new_title_edit(adc_list, tdc_list, folder_with_pngs, adc_titles, tdc_titles)
#      27 ax.set_title(tdc_titles[i])
#      28 new_img_path=folder_with_pngs+"\\"+"re_title"+"\\"+tdc_list[i]
# ---> 29 plt.savefig(new_img_path, bbox_inches="tight")
#      30 plt.close()
#      31 new_img=Image.open(new_img_path)
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3055, in _AxesBase._update_title_position(self, renderer)
#    3053     _log.debug('top of Axes not in the figure, so title not moved')
#    3054     return
# -> 3055 if title.get_window_extent(renderer).ymin < top:
#    3056     _, y = self.transAxes.inverted().transform((0, top))
#    3057     title.set_position((x, y))
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File c:\Users\svene\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:220, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     217     return width, height, descent
#     219 font = self._prepare_font(prop)
# --> 220 font.set_text(s, 0.0, flags=get_hinting_flag())
#     221 w, h = font.get_width_height()  # width and height of unrotated string
#     222 d = font.get_descent()
#
# KeyboardInterrupt:

# %%
# Get list of all spectra
all_folder=spectra_path+"\\"+"re_title"
all_files=os.listdir(all_folder)
# print(all_folder)
# print(all_files)

pngs=[]
for i in all_files:
    #print(i)
    if "TestData" in i:
        pngs.append(i)
#print(pngs)
        
# Create summary image with every spectra generated
concat_imgs(pngs, all_folder, 8, "All Images")

# %%
def dead_tube_check(input_file):
    df = pd.read_csv(input_file, delimiter=",")

    if len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)]) > 0:
        number=len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
        print(str(number) + " dead tubes are suppressed.")
        display(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
    else:
        display("There are no dead tubes.")

# %%
#Choose run of interest
def calc_stats_txt(input_txt_file, output_txt_folder):

    # import txt file as df
    df = pd.read_csv(input_txt_file, delimiter=",") #import txt file

    # check for dead tubes
    with open(output_txt_folder+"\\"+"stats.txt", "w") as file:
        if len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)]) > 0:
            number=len(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
            file.write(str(number) + " dead tubes are suppressed.\n")
            file.write("\n")
            file.write("Dead Tubes:\n")
            #display(df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)])
            df_dead=df.loc[(df['Resolution[um]']==0) & (df['Efficiency']==0)]
            df_string = df_dead.to_string(header=True, index=False)
            file.write(df_string + '\n')
            file.write("\n")
        else:
            file.write("There are no dead tubes.\n")
            file.write("\n")

    # find stats for only alive tubes
    df=df.loc[(df['Resolution[um]']>0) & (df['Efficiency']>0)] #select alive tubes
    mins=df.min().to_frame()
    mins.columns=["Min"]
    maxes=df.max().to_frame()
    maxes.columns=["Max"]
    means=df.mean().to_frame()
    means.columns=["Mean"]
    summary=pd.concat([mins,maxes,means],axis=1)
    summary=summary.drop(labels=["Column", "Layer", "TDC_id", "TDC_Ch_id"], axis=0, inplace=False)
    
    with open(output_txt_folder+"\\"+"stats.txt", 'a') as f:
        f.write("Statistics (excluding dead tubes):\n")
        df_string = summary.to_string(header=True, index=True)
        f.write(df_string + '\n')

    #summary.to_csv('output.txt', sep='\t', index=True)

    return

# %%
run=r"C:\Users\svene\OneDrive\Documents\Tufts\Research\qual\eye_scanning\Mod34_BIS5C10_CosmicRay_Thr108.txt"
# output_folder=r"C:\Users\svene\OneDrive\Documents\Tufts\Research\qual\working_files"
# avgs=calc_stats_txt(run,output_folder)

# %%
#call specific tdc and tdc id
df = pd.read_csv(run, delimiter=",")
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
#display(df.loc[(df['Column']==1) & (df['Layer']==3)])
display(df.loc[(df["ADC_peak[ns]"]<120)])
#display(df)
# Out:
#      Column  Layer  TDC_id  TDC_Ch_id      T0[ns]    TMax[ns]  ADC_peak[ns]  \
# 360      46      1      14         18  285.205761  193.621667    117.970477
# 363      46      4      14         17  282.375531  193.214569    100.000000
#
#      ADC_width[ns]  Resolution[um]  Efficiency
# 360       7.548115      108.617893    0.979641
# 363       6.783993      107.691934    0.991989
