# %%
# import required packages
import matplotlib.pyplot as plt

# import other functions
#from hist_func import *
from make_list_func import *
from summary_func import *
#from summary_stats_func import *

# %%
# define inputs
path_to_files = r"C:\Users\svene\OneDrive\Documents\Tufts\Research\qual\eye_scanning\Cosmic_Data"
extension_of_files = ".txt"

# %%
values = all_tube_data(path_to_files, extension_of_files, "Resolution[um]")

# %%
# once hist_func is made, have this all just be calling a function
plt.hist(values, bins=100, histtype="step", facecolor="none", edgecolor="blue")
plt.title("Resolution (um) of All Tubes in UM Chambers")
plt.xlabel("Resolution (um)")
plt.ylabel("Number of tubes")
plt.show()
